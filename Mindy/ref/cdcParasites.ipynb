# %%
# Dependencies
import os
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import html5lib

# %%
url = "https://www.cdc.gov/parasites/az/index.html#s"

# %%
# tables = pd.read_html(url)
# tables

# %%
 # Retrieve page with the requests module
response = requests.get(url)

# %%
# Create BeautifulSoup object; parse with 'html.parser'
soup = bs(response.text, 'html.parser')

# %%
   # Examine the results, then determine element that contains sought info
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 8]>
# <html class="no-js nav theme-blue lt-ie10 lt-ie9 lt-ie8 " lang="en-us"> <![endif]-->
# <!--[if IE 8]>
# <html class="no-js nav theme-blue lt-ie10 lt-ie9 " lang="en-us"> <![endif]-->
# <!--[if IE 9]>
# <html class="no-js nav theme-blue lt-ie10 " lang="en-us"> <![endif]-->
# <!--[if !IE]><!-->
# <html class="no-js nav theme-blue " lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    CDC - Parasites - Alphabetical Index of Parasitic Diseases
#   </title>
#   <meta content="A parasite is an organism that lives on or in a host and gets its food from or at the expense of its host. Parasites can cause disease in humans." name="description"/>
# ...

# %%
title = soup.title.text
print(title)
# Out:
# CDC - Parasites - Alphabetical Index of Parasitic Diseases

# %%
# Print all paragraph texts
paragraphs = soup.find_all('em')
for paragraph in paragraphs:
    print(paragraph.text)
# Out:
# Acanthamoeba
# Acanthamoeba
# Entamoeba histolytica
# Angiostrongylus
# Anisakis
# Pseudoterranova
# Ascaris
# Babesia
# Balantidium
# Baylisascaris
# Blastocystis hominis
# Capillaria
# Chilomastix mesnili
# Clonorchis
# Cryptosporidium
# Cyclospora
# Cystoisospora
# Isospora
# Dientamoeba fragilis
# Diphyllobothrium
# Dipylidium caninum
# Dirofilaria
# Dipylidium caninum
# Endolimax nana
# Entamoeba coli
# Entamoeba dispar
# Entamoeba hartmanni
# Entamoeba histolytica
# Entamoeba polecki
# Fasciola
# Fasciolopsis
# Giardia
# Gnathostoma
# Heterophyes
# Hymenolepis
# Ascaris
# Iodamoeba buetschlii
# Isospora
# Cystoisospora
# Leishmania
# Acanthamoeba
# Leishmania
# Loa loa
# Plasmodium
# Microsporidia
# Naegleria
# Toxocara
# Opisthorchis
# Paragonimus
# Plasmodium
# Pneumocystis jirovecii
# Pseudoterranova
# Anisakis
# Baylisascaris
# Sarcocystosis
# Strongyloides
# Taenia
# Taenia
# Toxocara
# Toxoplasma
# Trichomonas
# Trichuris
# Toxocara
# , Trichuris

# %%
soup.children

# %%
list(soup.children)
# Out:
# ['html',
#  '\n',
#  '[if lt IE 8]>\r\n<html class="no-js nav theme-blue lt-ie10 lt-ie9 lt-ie8 " lang="en-us"> <![endif]',
#  '\n',
#  '[if IE 8]>\r\n<html class="no-js nav theme-blue lt-ie10 lt-ie9 " lang="en-us"> <![endif]',
#  '\n',
#  '[if IE 9]>\r\n<html class="no-js nav theme-blue lt-ie10 " lang="en-us"> <![endif]',
#  '\n',
#  '[if !IE]><!',
#  '\n',
#  <html class="no-js nav theme-blue " lang="en-us"> <!--<![endif]-->
#  <head>
#  <meta charset="utf-8"/>
#  <title>CDC - Parasites - Alphabetical Index of Parasitic Diseases</title>
#  <meta content="A parasite is an organism that lives on or in a host and gets its food from or at the expense of its host. Parasites can cause disease in humans." name="description"/>
# ...

# %%
listingList = soup.find("div", class_="module-typeH")["em"]
listingList
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-61fb459f4dd8> in <module>
# ----> 1 listingList = soup.find("div", class_="module-typeH")["em"]
#       2 listingList
#
# ~\Anaconda3\envs\RunnersRun\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1069         """tag[key] returns the value of the 'key' attribute for the tag,
#    1070         and throws an exception if it's not there."""
# -> 1071         return self.attrs[key]
#    1072
#    1073     def __iter__(self):
#
# KeyError: 'em'

# %%
# div class "module-typeH"


# Print all paragraph texts
para = soup.find_all('div', class_='module-typeH','em')
for paragraph in paragraphs:
    print(paragraph.text)
# Out:
#   File "<ipython-input-13-c5f70ed31266>", line 5
#     para = soup.find_all(class = 'module-typeH','em')
#                              ^
# SyntaxError: invalid syntax

# %%
div class "module-typeH"


# Print all paragraph texts
para = soup.find_all('em')
for paragraph in paragraphs:
    print(paragraph.text)

# %%
para_df = pd.DataFrame(paragraphs)
para_df
# Out:
#                                                     0
# 0   <em><a href="/parasites/acanthamoeba/index.htm...
# 1   <em><a href="/parasites/acanthamoeba/index.htm...
# 2                      <em>Entamoeba histolytica</em>
# 3                            <em>Angiostrongylus</em>
# 4                                   <em>Anisakis</em>
# 5                            <em>Pseudoterranova</em>
# 6                                    <em>Ascaris</em>
# 7                                    <em>Babesia</em>
# 8                                <em>Balantidium</em>
# 9                              <em>Baylisascaris</em>
# 10  <em><a href="/parasites/blastocystis/index.htm...
# 11                                <em>Capillaria</em>
# 12  <em><a href="/parasites/nonpathprotozoa/index....
# 13                                <em>Clonorchis</em>
# 14                           <em>Cryptosporidium</em>
# 15                                <em>Cyclospora</em>
# ...

# %%
results = soup.find_all('em')
print(results)
# Out:
# [<em><a href="/parasites/acanthamoeba/index.html">Acanthamoeba</a></em>, <em><a href="/parasites/acanthamoeba/index.html">Acanthamoeba</a></em>, <em>Entamoeba histolytica</em>, <em>Angiostrongylus</em>, <em>Anisakis</em>, <em>Pseudoterranova</em>, <em>Ascaris</em>, <em>Babesia</em>, <em>Balantidium</em>, <em>Baylisascaris</em>, <em><a href="/parasites/blastocystis/index.html">Blastocystis hominis</a></em>, <em>Capillaria</em>, <em><a href="/parasites/nonpathprotozoa/index.html">Chilomastix mesnili</a></em>, <em>Clonorchis</em>, <em>Cryptosporidium</em>, <em>Cyclospora</em>, <em><a href="/parasites/cystoisospora/index.html">Cystoisospora</a></em>, <em>Isospora</em>, <em><a href="/parasites/dientamoeba/index.html">Dientamoeba fragilis</a></em>, <em>Diphyllobothrium</em>, <em><a href="/parasites/dipylidium/index.html">Dipylidium caninum</a></em>, <em><a href="/parasites/dirofilariasis/index.html">Dirofilaria</a></em>, <em>Dipylidium caninum</em>, <em><a href="/parasites/nonpathprotozoa/
# ...

# %%
 # Loop through returned results
for result in results:
    # Error handling
    try:
        # Identify and return title of listing
        title = result.find('a', class_="result-title").text
        # Identify and return price of listing
        price = result.a.span.text
        # Identify and return link to listing
        link = result.a['href']

        # Print results only if title, price, and link are available
        if (title and price and link):
            print('-------------')
            print(title)
            print(price)
            print(link)
    except AttributeError as e:
        print(e)
# Out:
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# 'NoneType' object has no attribute 'text'
# ...
